# %% [markdown]
# # o que é ciência?
#
# 1. Conjunto de métodos para adquirir conhecimento.
# 2. Inicia-se com um processo observação.
# 3. Thomas Bayes: A doutrina dos fluxos.
#
# https://cienciahoje.org.br/artigo/thomas-bayes-o-cara/
#
#  Dois anos após sua morte, um amigo, o filósofo Richard Price (1723-1791), apresentou à Royal Society um artigo que aparentemente encontrou entre os papéis do reverendo, com o nome ‘ An essay towards solving a problem in the doctrine of chances ’ (‘Ensaio buscando resolver um problema na doutrina das probabilidades’). Nesse artigo estava a demonstração do famoso teorema de Bayes.
#
#  **Teorema de Bayes: Entendendo a Probabilidade com Exemplos do Dia a Dia**
#
# O **Teorema de Bayes** é uma ferramenta poderosa para calcular probabilidades condicionais. Vamos explorar essa fórmula passo a passo, usando exemplos simples e cotidianos.
#
# 1. **O que é o Teorema de Bayes?**
#    - O Teorema de Bayes é uma fórmula que nos permite atualizar probabilidades com base em novas evidências.
#    - Ele relaciona a probabilidade de um evento ocorrer, dado que outro evento já aconteceu.
#
# 2. **A Fórmula do Teorema de Bayes**
#    - A fórmula é a seguinte:
#      $$ P(A|B) = \frac{P(B|A) \cdot P(A)}{P(B)} $$
#      - **P(A|B)**: Probabilidade do evento **A** ocorrer, dado que o evento **B** já aconteceu.
#      - **P(B|A)**: Probabilidade do evento **B** ocorrer, dado que o evento **A** já aconteceu.
#      - **P(A)**: Probabilidade do evento **A** ocorrer.
#      - **P(B)**: Probabilidade do evento **B** ocorrer.
#
# 3. **Exemplo com Bolas Coloridas**
#    - Imagine uma caixa com duas bolas vermelhas e três bolas azuis.
#    - Se retirarmos duas bolas ao acaso (sem reposição), queremos saber:
#      - Qual a probabilidade da segunda bola ser vermelha, dado que a primeira foi azul?
#      - Qual a probabilidade da primeira bola ser azul, dado que a segunda será vermelha?
#    - Vamos aplicar o Teorema de Bayes:
#      - Primeiro, calculamos a probabilidade condicional:
#        $$ P(\text{segunda bola vermelha}|\text{primeira bola azul}) = \frac{2}{4} = \frac{1}{2} $$
#      - Agora, usamos o Teorema de Bayes para encontrar a segunda probabilidade:
#        $$ P(\text{primeira bola azul}|\text{segunda bola vermelha}) = \frac{P(\text{segunda bola vermelha}|\text{primeira bola azul}) \cdot P(\text{primeira bola azul})}{P(\text{segunda bola vermelha})} $$
#        $$ P(\text{primeira bola azul}|\text{segunda bola vermelha}) = \frac{\frac{1}{2} \cdot \frac{2}{5}}{\frac{3}{5}} = \frac{1}{3} $$
#
# 4. **Aplicações Práticas**
#    - Investidores usam o Teorema de Bayes para estimar probabilidades no mercado financeiro.
#    - Por exemplo, podemos calcular a chance de uma ação cair após uma queda geral no índice Bovespa.
#
# 5. **Conclusão**
#    - O Teorema de Bayes nos ajuda a atualizar nossas probabilidades com base em novas informações.
#    - Lembre-se sempre de ter alguma informação anterior para aplicar o teorema com sucesso.
#
# Espero que isso tenha sido útil! Se tiver mais perguntas, estou à disposição. 😊
#
# Fonte: conversa com o Copilot, 03/06/2024
# (1) TEOREMA DE BAYES | Cálculo de Probabilidade | Responde Aí. https://www.youtube.com/watch?v=goaRH7a5hR4.
# (2) Bayes' Theorem EXPLAINED with Examples. https://www.youtube.com/watch?v=cqTwHnNbc8g.
# (3) Teorema de Bayes. https://www.youtube.com/watch?v=9OOZf4klOeM.
# (4) Teorema de Bayes: Entenda o que é e como calcular - Suno. https://www.suno.com.br/artigos/teorema-de-bayes/.
# (5) Descubre la fórmula del teorema de Bayes y su explicación. https://teoremas.net/bayes/teorema-de-bayes-formula-explicada/.
# (6) Calculadora passo a passo de regras de Bayes - MathCracker.com. https://mathcracker.com/pt/calculadora-regra-bayes.
# (7) Teorema de Bayes: O que é, Resumo e Exercícios Resolvidos - Responde Aí. https://www.respondeai.com.br/conteudo/probabilidade-e-estatistica/calculo-de-probabilidades/teorema-de-bayes/830

# %% [markdown]
# # GPT
#
# 1. Inteligência Artificial Generativa
#
# -Texto que gera texto
# -Texto que gera imagem
# -Texto que gera vídeo
# -Texto que gera audio
#
# 2. PLN (Processamento de Linguagem Natural)
#
# -Mineração de Texto em Documentos
# -Estudio de Documento Inteligente
#
# # ChatBots
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Mineração de Textos em Documentos
#
# -Laboratório : Ler palavras dentro de uma imagem (recibo)
#
# 1. Entrar no Estudio de Documento Inteligente
#   ◦Azure AI Document Intelligence
#   ◦Documentos Inteligentes baseado em OCR(ler texto impresso ou manuscrito)
#
#   ![image.png](attachment:image.png)
#
#   ![image-2.png](attachment:image-2.png)
